# %%
import random
numbers =random.randint(1, 10)
user_number = int(input("Guess a number between 1 and 10: "))
if user_number == numbers:
  print ("You are win")
else:
  print("You are lose.Number was:", numbers)

# %%
user_name=input("What is your name? ")
user_age=input("What is your age? ")
age=int(user_age)+1
print("Hello", user_name, "Next year you will be", age)

# %%
import random
word=input("Enter a word: ")
for i in range(5):
    random_string = ""
    
    for j in range(len(word)):
        random_string =random_string + random.choice(word)
    
    print(random_string)
